# %% [markdown]
# <H1>Start

# %% [markdown]
# <h2>Some housekeeping

# %% [markdown]
# <h2>These codes work in both windows and macintosh operating systems, as long as the Python version is 3.11 and above.

# %% [markdown]
# Check your version

# %%
from platform import python_version
print(python_version())
# Out:
# 3.12.7

# %% [markdown]
# If the codes are not running, i.e., no output cells, no error messages, retart the Kernel, go to 'Kernel' at the top of the tool bar, choose "Retart Kernel"

# %% [markdown]
# Use the "run" button in the tool bar to executive the codes in each cell, or hightlight the cell then "shift + enter". You can do a "Run All Cells" under the "Run" function in the tool bar to run all the codes in once.

# %% [markdown]
# <h1>The Basics of Python coding

# %% [markdown]
# <h1>Understand the different types of variables and the associated operators

# %% [markdown]
# `first_name`, `second_name`, `name` are the created variables. Enter inputs in the right hand side of the "=". Use " " for string variables,

# %%
first_name = "Taylor"
second_name = "Swift"
name = first_name + " " + second_name
print(name)

number_t=name.count('t') #count the number of t in name
print("Times t appears in the name is:",number_t)

Age_years = 35
Age_hours = round(24*365.25*Age_years)#default value of the round function is 0
print("Age_hours is:",Age_hours,".")

month = 12
day = 13
if month > day:
    print("month > day")
else:
    print("Month is not greater than day.")


name = "Taylor Swift"
print('YOU ROCK' + ' ' + name.upper() + '!') #upper(): upper case
# Out:
# Taylor Swift
# Times t appears in the name is: 1
# Age_hours is: 306810 .
# Month is not greater than day.
# YOU ROCK TAYLOR SWIFT!

# %% [markdown]
# <h2>Run the following codes will create 4 files, DATA.csv, correlation_matrix_heatmap.png, summary_output.xlsx, and panel_ols_summary_output.xlsx. All files created will be stored under the same folder as this jupyter notebook. Make sure your group_{number}_data.csv is in the same folder as this jupyter notebook "PythonAnalysis" in order to run this notebook properly.
#
# <h2>Suggested steps:
#
# <h3>Understand the notebook as a whole. Refer to relevant sections in the lecture notes and other reference materials, such as teaching notes, the 'Assessment-Details' document and research papers, to grasp the key concepts and the purpose of this project.
#
# <h3>You can break the jupyter notebook into TWO main sections:
#
# <h3>1. Focus on understanding the Perform Exploratory Data Analysis, which involves manipulating dataframes and preparing data for Principal Component Analysis (PCA).
#
# <h3>2. Regression analysis; compare and contrast different models to comprehend their purposes fully.

# %% [markdown]
# <h1>PART ONE

# %% [markdown]
# <h2> Step 1: Import the libraries

# %%
import matplotlib.pyplot as plt #data visulisation package
import pandas as pd #pandas to create dataframe
import seaborn as sns #seaborn for graph plots
import numpy as np #numpy for data manipulation

# %% [markdown]
# <h2>Step 2: Understand the data using pandas

# %% [markdown]
# Read the csv file you just scraped using the "student_scraper.ipynp" file into a dataframe in pandas as 'group_1_data.csv' (the name on the left hand side of the "=") is the name of the dataframe we create, you can use whatever name that suits; the csv file name (on the right hand side of the "=") your group scraped is not going to be 'group_1_data.csv', it will be 'group_#_data.csv', the # is the group number your lecturer allocates to your group.

# %%
group_53_data=pd.read_csv("group_53_data.csv")

# %% [markdown]
# <h3>Perform Exploratory Data Analysis (EDA)

# %% [markdown]
# Find out the data rows and columns. The first value=number of rows, the second value=number of columns. This sample dataset has 40 firm-year observations and 11 variables. The next line of code shows what these 11 variables are. **Report the total observations in your report**.

# %%
group_53_data.shape
# Out:
# (756, 11)

# %% [markdown]
# Display the data, python starts the row and column from 0, not 1; hence the last row = (number of rows -1)

# %%
group_53_data
# Out:
#     Company-Year            Sector  stock_FinancialYEnd  \
# 0       ADM-2020  Consumer Staples            52.451912
# 1       ADM-2021  Consumer Staples            85.068222
# 2       ADM-2022  Consumer Staples            76.502960
# 3       ADM-2023  Consumer Staples            61.717091
# 4       AEE-2020         Utilities            73.438469
# ..           ...               ...                  ...
# 751     ZBH-2023       Health Care           131.440140
# 752     ZTS-2020       Health Care           152.921402
# 753     ZTS-2021       Health Care           184.139954
# 754     ZTS-2022       Health Care           163.704971
# 755     ZTS-2023       Health Care           167.947601
#
#      stock_FollowingQtrEnd  BasicEPS total shareholder's equity  \
# 0                56.154476      3.19                 20,000,000
# 1                73.524879      4.84                 22,477,000
# 2                72.962646      7.93                 24,284,000
# 3                59.959892      6.44                 24,132,000
# 4                72.786613      3.53                  8,938,000
# ..                     ...       ...                        ...
# 751             108.289314      4.91                 12,480,500
# 752             181.245895      3.44                  3,769,000
# 753             168.103531      4.29                  4,543,000
# 754             169.778137      4.51                  4,405,000
# 755             172.456879      5.08                  4,997,000
#
#     Basic avg shares NetIncomeAvailShareholders  ESG Risk Exposure Score  \
# 0            556,000                  1,772,000                   58.750
# 1            560,000                  2,709,000                   58.933
# 2            547,000                  4,340,000                   60.100
# 3            541,000                  3,483,000                   57.162
# 4            247,000                    871,000                   64.695
# ..               ...                        ...                      ...
# 751          208,700                  1,024,000                   48.800
# 752          475,502                  1,638,000                   39.417
# 753          474,300                  2,037,000                   36.067
# 754          468,900                  2,114,000                   35.588
# 755          461,200                  2,344,000                   35.100
#
#      ESG Risk Managed Score  Sustainalytics ESG Risk Classification
# 0                    24.183                                   7.000
# 1                    24.282                                   7.000
# 2                    23.715                                   7.000
# 3                    24.278                                   7.000
# 4                    28.425                                   7.545
# ..                      ...                                     ...
# 751                  22.318                                   5.000
# 752                  11.943                                   5.000
# 753                  15.637                                   3.667
# 754                  17.158                                   3.000
# 755                  16.152                                   3.000
#
# [756 rows x 11 columns]

# %% [markdown]
# List the *fist* five rows of the data

# %%
group_53_data.head() #default is 5, can put any number in ()
# Out:
#   Company-Year            Sector  stock_FinancialYEnd  stock_FollowingQtrEnd  \
# 0     ADM-2020  Consumer Staples            52.451912              56.154476
# 1     ADM-2021  Consumer Staples            85.068222              73.524879
# 2     ADM-2022  Consumer Staples            76.502960              72.962646
# 3     ADM-2023  Consumer Staples            61.717091              59.959892
# 4     AEE-2020         Utilities            73.438469              72.786613
#
#    BasicEPS total shareholder's equity Basic avg shares  \
# 0      3.19                 20,000,000          556,000
# 1      4.84                 22,477,000          560,000
# 2      7.93                 24,284,000          547,000
# 3      6.44                 24,132,000          541,000
# 4      3.53                  8,938,000          247,000
#
#   NetIncomeAvailShareholders  ESG Risk Exposure Score  ESG Risk Managed Score  \
# 0                  1,772,000                   58.750                  24.183
# 1                  2,709,000                   58.933                  24.282
# 2                  4,340,000                   60.100                  23.715
# 3                  3,483,000                   57.162                  24.278
# 4                    871,000                   64.695                  28.425
#
#    Sustainalytics ESG Risk Classification
# 0                                   7.000
# 1                                   7.000
# 2                                   7.000
# 3                                   7.000
# 4                                   7.545

# %% [markdown]
# List the *last* five rows of the data

# %%
group_53_data.tail()
# Out:
#     Company-Year       Sector  stock_FinancialYEnd  stock_FollowingQtrEnd  \
# 751     ZBH-2023  Health Care           131.440140             108.289314
# 752     ZTS-2020  Health Care           152.921402             181.245895
# 753     ZTS-2021  Health Care           184.139954             168.103531
# 754     ZTS-2022  Health Care           163.704971             169.778137
# 755     ZTS-2023  Health Care           167.947601             172.456879
#
#      BasicEPS total shareholder's equity Basic avg shares  \
# 751      4.91                 12,480,500          208,700
# 752      3.44                  3,769,000          475,502
# 753      4.29                  4,543,000          474,300
# 754      4.51                  4,405,000          468,900
# 755      5.08                  4,997,000          461,200
#
#     NetIncomeAvailShareholders  ESG Risk Exposure Score  \
# 751                  1,024,000                   48.800
# 752                  1,638,000                   39.417
# 753                  2,037,000                   36.067
# 754                  2,114,000                   35.588
# 755                  2,344,000                   35.100
#
#      ESG Risk Managed Score  Sustainalytics ESG Risk Classification
# 751                  22.318                                   5.000
# 752                  11.943                                   5.000
# 753                  15.637                                   3.667
# 754                  17.158                                   3.000
# 755                  16.152                                   3.000

# %% [markdown]
# <h5>Check if any column has missing values

# %% [markdown]
# If the second column in the output cell is all 0 means there is no missing observations. If ther is non-0 in the second column, consider dropping these variables (columns) or use other extrapoliation methods to fill the missing values. **Report your findings**.

# %%
group_53_data.isnull().sum()
# Out:
# Company-Year                              0
# Sector                                    0
# stock_FinancialYEnd                       0
# stock_FollowingQtrEnd                     0
# BasicEPS                                  0
# total shareholder's equity                0
# Basic avg shares                          0
# NetIncomeAvailShareholders                0
# ESG Risk Exposure Score                   0
# ESG Risk Managed Score                    0
# Sustainalytics ESG Risk Classification    0
# dtype: int64

# %% [markdown]
# List all the columns names

# %%
group_53_data.columns
# Out:
# Index(['Company-Year', 'Sector', 'stock_FinancialYEnd',
#        'stock_FollowingQtrEnd', 'BasicEPS', 'total shareholder's equity',
#        'Basic avg shares', 'NetIncomeAvailShareholders',
#        'ESG Risk Exposure Score', 'ESG Risk Managed Score',
#        'Sustainalytics ESG Risk Classification'],
#       dtype='object')

# %% [markdown]
# List selected columns: `Company-Year`, `stock_FinancialYEnd`

# %%
group_53_data[['Company-Year', 'stock_FinancialYEnd']]
# Out:
#     Company-Year  stock_FinancialYEnd
# 0       ADM-2020            52.451912
# 1       ADM-2021            85.068222
# 2       ADM-2022            76.502960
# 3       ADM-2023            61.717091
# 4       AEE-2020            73.438469
# ..           ...                  ...
# 751     ZBH-2023           131.440140
# 752     ZTS-2020           152.921402
# 753     ZTS-2021           184.139954
# 754     ZTS-2022           163.704971
# 755     ZTS-2023           167.947601
#
# [756 rows x 2 columns]

# %% [markdown]
# List the first 2 rows of the selected columns

# %%
group_53_data[0:2][['ESG Risk Exposure Score', 'ESG Risk Managed Score']]
# Out:
#    ESG Risk Exposure Score  ESG Risk Managed Score
# 0                   58.750                  24.183
# 1                   58.933                  24.282

# %% [markdown]
# Show the observatoins under the `Sector` column.

# %%
group_53_data[['Sector']]
# Out:
#                Sector
# 0    Consumer Staples
# 1    Consumer Staples
# 2    Consumer Staples
# 3    Consumer Staples
# 4           Utilities
# ..                ...
# 751       Health Care
# 752       Health Care
# 753       Health Care
# 754       Health Care
# 755       Health Care
#
# [756 rows x 1 columns]

# %% [markdown]
# Find out the data type of `Sector`. If the answer is *float* or *int*, the variable is stored as a number; if it is *object* then the variable is stored as a string, pandas only reads *float* and *int* as numbers. At a later step, we will covert the string variables into *float* or *int* in order to run regression analysis.

# %%
print(group_53_data['Sector'].dtype)
# Out:
# object

# %% [markdown]
# List the unique values under `Sector`, **report the findings**.

# %%
pd.unique(group_53_data['Sector'])
# Out:
# array(['Consumer Staples', 'Utilities', 'Information Technology',
#        'Materials', 'Health Care', 'Industrials', 'Real Estate',
#        'Financials', 'Energy', 'Communication Services'], dtype=object)

# %% [markdown]
# How many rows (firms) under each `Sector`? **Report the findings.**

# %%
group_53_data['Sector'].value_counts()
# Out:
# Sector
# Utilities                 80
# Information Technology    80
# Materials                 80
# Health Care               80
# Industrials               80
# Real Estate               80
# Financials                80
# Energy                    80
# Consumer Staples          60
# Communication Services    56
# Name: count, dtype: int64

# %% [markdown]
# <h4>Boolean indexing

# %% [markdown]
# Find out what company is not in the "Energy" sector, "True" means that the company is not in the Energy sector.

# %%
group_53_data['Sector']!='Energy'
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 751    True
# 752    True
# 753    True
# 754    True
# 755    True
# Name: Sector, Length: 756, dtype: bool

# %% [markdown]
# Filter the data with the boolean indexing: only show data that are not in the "Energy" sector using "!="

# %%
group_53_data[group_53_data['Sector'] != 'Energy']
# Out:
#     Company-Year            Sector  stock_FinancialYEnd  \
# 0       ADM-2020  Consumer Staples            52.451912
# 1       ADM-2021  Consumer Staples            85.068222
# 2       ADM-2022  Consumer Staples            76.502960
# 3       ADM-2023  Consumer Staples            61.717091
# 4       AEE-2020         Utilities            73.438469
# ..           ...               ...                  ...
# 751     ZBH-2023       Health Care           131.440140
# 752     ZTS-2020       Health Care           152.921402
# 753     ZTS-2021       Health Care           184.139954
# 754     ZTS-2022       Health Care           163.704971
# 755     ZTS-2023       Health Care           167.947601
#
#      stock_FollowingQtrEnd  BasicEPS total shareholder's equity  \
# 0                56.154476      3.19                 20,000,000
# 1                73.524879      4.84                 22,477,000
# 2                72.962646      7.93                 24,284,000
# 3                59.959892      6.44                 24,132,000
# 4                72.786613      3.53                  8,938,000
# ..                     ...       ...                        ...
# 751             108.289314      4.91                 12,480,500
# 752             181.245895      3.44                  3,769,000
# 753             168.103531      4.29                  4,543,000
# 754             169.778137      4.51                  4,405,000
# 755             172.456879      5.08                  4,997,000
#
#     Basic avg shares NetIncomeAvailShareholders  ESG Risk Exposure Score  \
# 0            556,000                  1,772,000                   58.750
# 1            560,000                  2,709,000                   58.933
# 2            547,000                  4,340,000                   60.100
# 3            541,000                  3,483,000                   57.162
# 4            247,000                    871,000                   64.695
# ..               ...                        ...                      ...
# 751          208,700                  1,024,000                   48.800
# 752          475,502                  1,638,000                   39.417
# 753          474,300                  2,037,000                   36.067
# 754          468,900                  2,114,000                   35.588
# 755          461,200                  2,344,000                   35.100
#
#      ESG Risk Managed Score  Sustainalytics ESG Risk Classification
# 0                    24.183                                   7.000
# 1                    24.282                                   7.000
# 2                    23.715                                   7.000
# 3                    24.278                                   7.000
# 4                    28.425                                   7.545
# ..                      ...                                     ...
# 751                  22.318                                   5.000
# 752                  11.943                                   5.000
# 753                  15.637                                   3.667
# 754                  17.158                                   3.000
# 755                  16.152                                   3.000
#
# [676 rows x 11 columns]

# %% [markdown]
# Find out how many companies are NOT in the 'Energy' sector. In this output, the first number is the number of observations, i.e., companies. **Report your findings**.

# %%
group_53_data[group_53_data['Sector'] != 'Energy'].shape
# Out:
# (676, 11)

# %% [markdown]
# What are the 10 highest year-end `stock_FinancialYEnd` stock prices, the 10 highest quarter after the year-end `stock_FollowingQtrEnd` stock prices? **Report your findings**.

# %%
group_53_data.nlargest(10, ['stock_FinancialYEnd'])
# Out:
#     Company-Year                  Sector  stock_FinancialYEnd  \
# 407     LLY-2023             Health Care           775.277283
# 451    MPWR-2023  Information Technology           675.106934
# 144    CHTR-2020  Communication Services           617.020020
# 487    NFLX-2023  Communication Services           607.330017
# 80      BIO-2020             Health Care           571.169983
# 81      BIO-2021             Health Care           563.229980
# 145    CHTR-2021  Communication Services           545.520020
# 24     ALGN-2020             Health Care           541.530029
# 484    NFLX-2020  Communication Services           521.659973
# 450    MPWR-2022  Information Technology           494.965607
#
#      stock_FollowingQtrEnd  BasicEPS total shareholder's equity  \
# 407             903.839417      5.83                 10,771,900
# 451             820.413086      8.98                  2,049,939
# 144             721.450012     15.85                 23,805,000
# 487             674.880005     12.25                 20,588,313
# 80              644.289978    128.13                  9,879,940
# 81              495.000000    142.61                 13,685,236
# 145             468.529999     25.34                 14,050,000
# 24              611.000000     22.55                  3,233,865
# 484             528.210022      6.26                 11,065,240
# 450             535.304016      9.37                  1,668,602
#
#     Basic avg shares NetIncomeAvailShareholders  ESG Risk Exposure Score  \
# 407          899,379                  5,240,400                   48.350
# 451           47,610                    427,374                   31.233
# 144          203,316                  3,222,000                   28.150
# 487          441,571                  5,407,990                   24.163
# 80            29,768                  3,814,229                   30.233
# 81            29,831                  4,254,257                   30.350
# 145          183,669                  4,654,000                   33.933
# 24            78,760                  1,775,888                   27.700
# 484          440,922                  2,761,395                   23.100
# 450           46,727                    437,672                   31.300
#
#      ESG Risk Managed Score  Sustainalytics ESG Risk Classification
# 407                  24.018                                   5.000
# 451                  11.054                                   4.333
# 144                   8.101                                   4.167
# 487                   7.810                                   3.000
# 80                    8.757                                   5.000
# 81                    9.562                                   5.000
# 145                  11.113                                   5.000
# 24                    7.253                                   5.000
# 484                   5.112                                   3.000
# 450                  10.433                                   5.000

# %%
group_53_data.nlargest(10, ['stock_FollowingQtrEnd'])
# Out:
#     Company-Year                  Sector  stock_FinancialYEnd  \
# 407     LLY-2023             Health Care           775.277283
# 451    MPWR-2023  Information Technology           675.106934
# 144    CHTR-2020  Communication Services           617.020020
# 487    NFLX-2023  Communication Services           607.330017
# 80      BIO-2020             Health Care           571.169983
# 24     ALGN-2020             Health Care           541.530029
# 450    MPWR-2022  Information Technology           494.965607
# 484    NFLX-2020  Communication Services           521.659973
# 687     UNH-2023             Health Care           490.675934
# 435    META-2023  Communication Services           484.584198
#
#      stock_FollowingQtrEnd  BasicEPS total shareholder's equity  \
# 407             903.839417      5.83                 10,771,900
# 451             820.413086      8.98                  2,049,939
# 144             721.450012     15.85                 23,805,000
# 487             674.880005     12.25                 20,588,313
# 80              644.289978    128.13                  9,879,940
# 24              611.000000     22.55                  3,233,865
# 450             535.304016      9.37                  1,668,602
# 484             528.210022      6.26                 11,065,240
# 687             507.108704     24.12                 88,756,000
# 435             503.719879     15.19                153,168,000
#
#     Basic avg shares NetIncomeAvailShareholders  ESG Risk Exposure Score  \
# 407          899,379                  5,240,400                   48.350
# 451           47,610                    427,374                   31.233
# 144          203,316                  3,222,000                   28.150
# 487          441,571                  5,407,990                   24.163
# 80            29,768                  3,814,229                   30.233
# 24            78,760                  1,775,888                   27.700
# 450           46,727                    437,672                   31.300
# 484          440,922                  2,761,395                   23.100
# 687          928,000                 22,381,000                   33.200
# 435        2,574,000                 39,098,000                   47.775
#
#      ESG Risk Managed Score  Sustainalytics ESG Risk Classification
# 407                  24.018                                   5.000
# 451                  11.054                                   4.333
# 144                   8.101                                   4.167
# 487                   7.810                                   3.000
# 80                    8.757                                   5.000
# 24                    7.253                                   5.000
# 450                  10.433                                   5.000
# 484                   5.112                                   3.000
# 687                  17.900                                   3.000
# 435                  13.502                                   7.000

# %% [markdown]
# Split the `Company-Year` column into two columns: Company, Year

# %%
group_53_data[['Company', 'Year']] = group_53_data['Company-Year'].str.split('-', expand=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 group_53_data[['Company', 'Year']] = group_53_data['Company-Year'].str.split('-', expand=True)
#
# NameError: name 'group_53_data' is not defined

# %% [markdown]
# Check the columns

# %%
group_53_data.head()
# Out:
#   Company-Year            Sector  stock_FinancialYEnd  stock_FollowingQtrEnd  \
# 0     ADM-2020  Consumer Staples            52.451912              56.154476
# 1     ADM-2021  Consumer Staples            85.068222              73.524879
# 2     ADM-2022  Consumer Staples            76.502960              72.962646
# 3     ADM-2023  Consumer Staples            61.717091              59.959892
# 4     AEE-2020         Utilities            73.438469              72.786613
#
#    BasicEPS total shareholder's equity Basic avg shares  \
# 0      3.19                 20,000,000          556,000
# 1      4.84                 22,477,000          560,000
# 2      7.93                 24,284,000          547,000
# 3      6.44                 24,132,000          541,000
# 4      3.53                  8,938,000          247,000
#
#   NetIncomeAvailShareholders  ESG Risk Exposure Score  ESG Risk Managed Score  \
# 0                  1,772,000                   58.750                  24.183
# 1                  2,709,000                   58.933                  24.282
# 2                  4,340,000                   60.100                  23.715
# 3                  3,483,000                   57.162                  24.278
# 4                    871,000                   64.695                  28.425
#
#    Sustainalytics ESG Risk Classification Company  Year
# 0                                   7.000     ADM  2020
# 1                                   7.000     ADM  2021
# 2                                   7.000     ADM  2022
# 3                                   7.000     ADM  2023
# 4                                   7.545     AEE  2020

# %% [markdown]
# Rename the dataframe from 'group_1_data' to 'DATA' for easy typing. You can rename it in a different name but must rember the new dataframe name in the future steps or pandas won't recognise it.

# %%
DATA=group_53_data

# %% [markdown]
# Check the data under the renamed dataframe

# %%
DATA.head()
# Out:
#   Company-Year            Sector  stock_FinancialYEnd  stock_FollowingQtrEnd  \
# 0     ADM-2020  Consumer Staples            52.451912              56.154476
# 1     ADM-2021  Consumer Staples            85.068222              73.524879
# 2     ADM-2022  Consumer Staples            76.502960              72.962646
# 3     ADM-2023  Consumer Staples            61.717091              59.959892
# 4     AEE-2020         Utilities            73.438469              72.786613
#
#    BasicEPS total shareholder's equity Basic avg shares  \
# 0      3.19                 20,000,000          556,000
# 1      4.84                 22,477,000          560,000
# 2      7.93                 24,284,000          547,000
# 3      6.44                 24,132,000          541,000
# 4      3.53                  8,938,000          247,000
#
#   NetIncomeAvailShareholders  ESG Risk Exposure Score  ESG Risk Managed Score  \
# 0                  1,772,000                   58.750                  24.183
# 1                  2,709,000                   58.933                  24.282
# 2                  4,340,000                   60.100                  23.715
# 3                  3,483,000                   57.162                  24.278
# 4                    871,000                   64.695                  28.425
#
#    Sustainalytics ESG Risk Classification Company  Year
# 0                                   7.000     ADM  2020
# 1                                   7.000     ADM  2021
# 2                                   7.000     ADM  2022
# 3                                   7.000     ADM  2023
# 4                                   7.545     AEE  2020

# %% [markdown]
# Reorder the columns so `Company` and `Year` are at the front

# %%
DATA=DATA[['Company', 'Year','Company-Year', 'Sector', 'stock_FinancialYEnd', 'stock_FollowingQtrEnd', 
           'BasicEPS', "total shareholder's equity",'Basic avg shares', 'NetIncomeAvailShareholders', 
           'ESG Risk Exposure Score', 'ESG Risk Managed Score', 'Sustainalytics ESG Risk Classification']]

# %% [markdown]
# Drop the column `Company-Year`

# %%
DATA = DATA.drop(columns=['Company-Year'])

# %% [markdown]
# For fixed effect analyses later, map each unique `Sector` with a dummy code and create a new variable/column `SECTOR`. *In your scraped data, the `Sectors` maybe different, check what sectors you have first before the mapping*. **Report the process**.

# %%
DATA['Sector'] = DATA['Sector'].astype('category')
 
DATA['SECTOR'] = DATA['Sector'].cat.codes + 1
 
sector_mapping = dict(enumerate(DATA['Sector'].cat.categories, start=1))
print("Sector Mapping:\n", sector_mapping)
# Out:
# Sector Mapping:
#  {1: 'Communication Services', 2: 'Consumer Staples', 3: 'Energy', 4: 'Financials', 5: 'Health Care', 6: 'Industrials', 7: 'Information Technology', 8: 'Materials', 9: 'Real Estate', 10: 'Utilities'}

# %% [markdown]
# Check your data and **reporting the process**.

# %%
DATA.head()
# Out:
#   Company  Year            Sector  stock_FinancialYEnd  stock_FollowingQtrEnd  \
# 0     ADM  2020  Consumer Staples            52.451912              56.154476
# 1     ADM  2021  Consumer Staples            85.068222              73.524879
# 2     ADM  2022  Consumer Staples            76.502960              72.962646
# 3     ADM  2023  Consumer Staples            61.717091              59.959892
# 4     AEE  2020         Utilities            73.438469              72.786613
#
#    BasicEPS total shareholder's equity Basic avg shares  \
# 0      3.19                 20,000,000          556,000
# 1      4.84                 22,477,000          560,000
# 2      7.93                 24,284,000          547,000
# 3      6.44                 24,132,000          541,000
# 4      3.53                  8,938,000          247,000
#
#   NetIncomeAvailShareholders  ESG Risk Exposure Score  ESG Risk Managed Score  \
# 0                  1,772,000                   58.750                  24.183
# 1                  2,709,000                   58.933                  24.282
# 2                  4,340,000                   60.100                  23.715
# 3                  3,483,000                   57.162                  24.278
# 4                    871,000                   64.695                  28.425
#
#    Sustainalytics ESG Risk Classification  SECTOR
# 0                                   7.000       2
# 1                                   7.000       2
# 2                                   7.000       2
# 3                                   7.000       2
# 4                                   7.545      10

# %% [markdown]
# Reorder the columns

# %%
DATA=DATA[['Company', 'Year','SECTOR', 'Sector', 'stock_FinancialYEnd', 'stock_FollowingQtrEnd', 'BasicEPS', 
           "total shareholder's equity",'Basic avg shares', 'NetIncomeAvailShareholders', 
           'ESG Risk Exposure Score', 'ESG Risk Managed Score', 'Sustainalytics ESG Risk Classification']]

# %% [markdown]
# <h2>Step 3: Descriptive Statistics

# %% [markdown]
# First, check the data types to see whether data transformation/conversion is required. **Write the process in your report**, i.e., how many are "object", what are they, and why you need to convert/transform them.

# %%
print(DATA.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 13 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Company                                 756 non-null    object
#  1   Year                                    756 non-null    object
#  2   SECTOR                                  756 non-null    int8
#  3   Sector                                  756 non-null    category
#  4   stock_FinancialYEnd                     756 non-null    float64
#  5   stock_FollowingQtrEnd                   756 non-null    float64
#  6   BasicEPS                                756 non-null    float64
#  7   total shareholder's equity              756 non-null    object
#  8   Basic avg shares                        756 non-null    object
#  9   NetIncomeAvailShareholders              756 non-null    object
#  10  ESG Risk Exposure Score                 756 non-null    float64
#  11  ESG Risk Managed Score                  756 non-null    float64
#  12  Sustainalytics ESG Risk Classification  756 non-null    float64
# dtypes: category(1), float64(6), int8(1), object(5)
# memory usage: 66.9+ KB
# None

# %% [markdown]
# `Year`,`total shareholder's equity`,`Basic avg shares`, `NetIncomeAvailShareholders` are strings separated by ","; pandas reads them as strings and won't treat them as numbers, we first need to convert them into float type. **Write the process in your report**.

# %%
cols=["Year","total shareholder's equity",'Basic avg shares','NetIncomeAvailShareholders']
DATA[cols]=DATA[cols].apply(lambda x: pd.to_numeric(x.astype(str).str.replace(',',''), errors='coerce'))

# %% [markdown]
# Check your data again after the conversion

# %%
print(DATA.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 13 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Company                                 756 non-null    object
#  1   Year                                    756 non-null    int64
#  2   SECTOR                                  756 non-null    int8
#  3   Sector                                  756 non-null    category
#  4   stock_FinancialYEnd                     756 non-null    float64
#  5   stock_FollowingQtrEnd                   756 non-null    float64
#  6   BasicEPS                                756 non-null    float64
#  7   total shareholder's equity              756 non-null    int64
#  8   Basic avg shares                        756 non-null    int64
#  9   NetIncomeAvailShareholders              756 non-null    int64
#  10  ESG Risk Exposure Score                 756 non-null    float64
#  11  ESG Risk Managed Score                  756 non-null    float64
#  12  Sustainalytics ESG Risk Classification  756 non-null    float64
# dtypes: category(1), float64(6), int64(4), int8(1), object(1)
# memory usage: 66.9+ KB
# None

# %% [markdown]
# Round the selected variables into 2 decimal places

# %%
DATA.round({"stock_FinancialYEnd":2, "stock_FollowingQtrEnd":2, "ESG Risk Exposure Score":2, 
            "ESG Risk Managed Score":2, "Sustainalytics ESG Risk Classification":2 })
# Out:
#     Company  Year  SECTOR            Sector  stock_FinancialYEnd  \
# 0       ADM  2020       2  Consumer Staples                52.45
# 1       ADM  2021       2  Consumer Staples                85.07
# 2       ADM  2022       2  Consumer Staples                76.50
# 3       ADM  2023       2  Consumer Staples                61.72
# 4       AEE  2020      10         Utilities                73.44
# ..      ...   ...     ...               ...                  ...
# 751     ZBH  2023       5       Health Care               131.44
# 752     ZTS  2020       5       Health Care               152.92
# 753     ZTS  2021       5       Health Care               184.14
# 754     ZTS  2022       5       Health Care               163.70
# 755     ZTS  2023       5       Health Care               167.95
#
#      stock_FollowingQtrEnd  BasicEPS  total shareholder's equity  \
# 0                    56.15      3.19                    20000000
# 1                    73.52      4.84                    22477000
# 2                    72.96      7.93                    24284000
# 3                    59.96      6.44                    24132000
# 4                    72.79      3.53                     8938000
# ..                     ...       ...                         ...
# 751                 108.29      4.91                    12480500
# 752                 181.25      3.44                     3769000
# 753                 168.10      4.29                     4543000
# 754                 169.78      4.51                     4405000
# 755                 172.46      5.08                     4997000
#
#      Basic avg shares  NetIncomeAvailShareholders  ESG Risk Exposure Score  \
# 0              556000                     1772000                    58.75
# 1              560000                     2709000                    58.93
# 2              547000                     4340000                    60.10
# 3              541000                     3483000                    57.16
# 4              247000                      871000                    64.69
# ..                ...                         ...                      ...
# 751            208700                     1024000                    48.80
# 752            475502                     1638000                    39.42
# 753            474300                     2037000                    36.07
# 754            468900                     2114000                    35.59
# 755            461200                     2344000                    35.10
#
#      ESG Risk Managed Score  Sustainalytics ESG Risk Classification
# 0                     24.18                                    7.00
# 1                     24.28                                    7.00
# 2                     23.72                                    7.00
# 3                     24.28                                    7.00
# 4                     28.42                                    7.54
# ..                      ...                                     ...
# 751                   22.32                                    5.00
# 752                   11.94                                    5.00
# 753                   15.64                                    3.67
# 754                   17.16                                    3.00
# 755                   16.15                                    3.00
#
# [756 rows x 13 columns]

# %% [markdown]
# Create a new variable (book value to equity) `BVE`; **report the process**.

# %%
DATA['BVE'] = DATA["total shareholder's equity"] / DATA['Basic avg shares']

# %% [markdown]
# <h2>Step 4: PCA analysis

# %% [markdown]
# Import liabraries to run PCA

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %% [markdown]
# Create an index `esg_index` using PCA for all 3 ESG scores, and **report the process**.

# %%
esg_scores = DATA[['ESG Risk Exposure Score', 'ESG Risk Managed Score', 'Sustainalytics ESG Risk Classification']]

# %% [markdown]
# Standardise the features

# %%
scaler = StandardScaler()
esg_scores_scaled = scaler.fit_transform(esg_scores)

# %% [markdown]
# Apply PCA

# %%
pca = PCA(n_components=1)
esg_index = pca.fit_transform(esg_scores_scaled)

# %% [markdown]
# Create a new variable `ESG_Index` and add it to the dataframe

# %%
DATA['ESG_Index']=esg_index

# %%
DATA.head()
# Out:
#   Company  Year  SECTOR            Sector  stock_FinancialYEnd  \
# 0     ADM  2020       2  Consumer Staples            52.451912
# 1     ADM  2021       2  Consumer Staples            85.068222
# 2     ADM  2022       2  Consumer Staples            76.502960
# 3     ADM  2023       2  Consumer Staples            61.717091
# 4     AEE  2020      10         Utilities            73.438469
#
#    stock_FollowingQtrEnd  BasicEPS  total shareholder's equity  \
# 0              56.154476      3.19                    20000000
# 1              73.524879      4.84                    22477000
# 2              72.962646      7.93                    24284000
# 3              59.959892      6.44                    24132000
# 4              72.786613      3.53                     8938000
#
#    Basic avg shares  NetIncomeAvailShareholders  ESG Risk Exposure Score  \
# 0            556000                     1772000                   58.750
# 1            560000                     2709000                   58.933
# 2            547000                     4340000                   60.100
# 3            541000                     3483000                   57.162
# 4            247000                      871000                   64.695
#
#    ESG Risk Managed Score  Sustainalytics ESG Risk Classification        BVE  \
# 0                  24.183                                   7.000  35.971223
# 1                  24.282                                   7.000  40.137500
# 2                  23.715                                   7.000  44.394881
# 3                  24.278                                   7.000  44.606285
# 4                  28.425                                   7.545  36.186235
#
#    ESG_Index
# 0   1.582024
# 1   1.596993
# 2   1.614091
# 3   1.514517
# 4   2.316098

# %% [markdown]
# Check the variance loading, **report the variance loading in your report and interpret what the loading means**.

# %%
print("\nExplained variance ratio:", pca.explained_variance_ratio_[0])
# Out:
# Explained variance ratio: 0.803850268547764

# %% [markdown]
# Show the loadings (importance) of each ESG score in the index. The highest loading is component 1, Python will creat a PCA using the highest loading. **Report the loading**.

# %%
loadings = pd.DataFrame(
    pca.components_.T,
    columns=['Loading'],
    index=['ESG Risk Exposure Score', 'ESG Risk Managed Score', 'Sustainalytics ESG Risk Classification']
)
print("\nPCA Loadings:")
print(loadings)
# Out:
# PCA Loadings:
#                                          Loading
# ESG Risk Exposure Score                 0.640335
# ESG Risk Managed Score                  0.553209
# Sustainalytics ESG Risk Classification  0.532852

# %% [markdown]
# ***Correlation matrix***

# %% [markdown]
# Perform correlation analysis and print out the heatmap.

# %% [markdown]
# Must specify the non-string variables otherwise the corr() code won't run. Save the matrix heatmap, **include it in your report**.

# %%
correlation_matrix = DATA[
    ['SECTOR', 'stock_FinancialYEnd', 'stock_FollowingQtrEnd', 'BasicEPS', "total shareholder's equity",
     'Basic avg shares', 'NetIncomeAvailShareholders', 'ESG Risk Exposure Score', 'ESG Risk Managed Score', 
     'Sustainalytics ESG Risk Classification', 'BVE', 'ESG_Index']
].corr()

plt.figure(figsize=(10, 8)) # Set up the matplotlib figure
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', center=0, fmt=".2f", linewidths=.5)
plt.title('Correlation Matrix Heatmap')

plt.savefig('correlation_matrix_heatmap.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# Rename the columns, the statsmodels library does not recognise variables with 'space'.

# %%
DATA.rename(columns={"NetIncomeAvailShareholders": "profit", 
                     "ESG Risk Exposure Score": "ESG_Exposure", 
                     "ESG Risk Managed Score": "ESG_Managed", 
                     "Sustainalytics ESG Risk Classification": "ESG_Class"}, inplace=True)

# %% [markdown]
# Check the dataframe after renaming

# %%
DATA.head()
# Out:
#   Company  Year  SECTOR            Sector  stock_FinancialYEnd  \
# 0     ADM  2020       2  Consumer Staples            52.451912
# 1     ADM  2021       2  Consumer Staples            85.068222
# 2     ADM  2022       2  Consumer Staples            76.502960
# 3     ADM  2023       2  Consumer Staples            61.717091
# 4     AEE  2020      10         Utilities            73.438469
#
#    stock_FollowingQtrEnd  BasicEPS  total shareholder's equity  \
# 0              56.154476      3.19                    20000000
# 1              73.524879      4.84                    22477000
# 2              72.962646      7.93                    24284000
# 3              59.959892      6.44                    24132000
# 4              72.786613      3.53                     8938000
#
#    Basic avg shares   profit  ESG_Exposure  ESG_Managed  ESG_Class        BVE  \
# 0            556000  1772000        58.750       24.183      7.000  35.971223
# 1            560000  2709000        58.933       24.282      7.000  40.137500
# 2            547000  4340000        60.100       23.715      7.000  44.394881
# 3            541000  3483000        57.162       24.278      7.000  44.606285
# 4            247000   871000        64.695       28.425      7.545  36.186235
#
#    ESG_Index
# 0   1.582024
# 1   1.596993
# 2   1.614091
# 3   1.514517
# 4   2.316098

# %% [markdown]
# Save the new dataframe to csv

# %%
DATA.to_csv('DATA.csv')

# %% [markdown]
# <h1>PART TWO

# %% [markdown]
# <h2>Regression Analysis

# %% [markdown]
# We have provided a few different stats models here; choose the best model to interpet the results. Due to the random data scraping, you may find some models perform better/poorer, **export the results and include them in your report as sensitive analyses and state that you have tried other models**. Focus on interpretting the model(s) that yield the best results, i.e., with significant parameters (p-value<10%) of `BVE`, `BasicEPS`, `4 ESG scores` (try one score at a time, four scores in one model may not run as they are correlated).

# %% [markdown]
# <h2>Install fixed effect model and statsmodels

# %%
# %pip install FixedEffectModel
import statsmodels.api as sm
import statsmodels.formula.api as smf
# Out:
# Collecting FixedEffectModelNote: you may need to restart the kernel to use updated packages.
#
#   Downloading FixedEffectModel-0.0.5-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: pandas>=0.16.0 in c:\users\86186\anaconda3\lib\site-packages (from FixedEffectModel) (2.2.2)
# Requirement already satisfied: numpy>=1.9.2 in c:\users\86186\anaconda3\lib\site-packages (from FixedEffectModel) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\86186\anaconda3\lib\site-packages (from FixedEffectModel) (1.13.1)
# Requirement already satisfied: statsmodels>=0.12.2 in c:\users\86186\anaconda3\lib\site-packages (from FixedEffectModel) (0.14.2)
# Requirement already satisfied: networkx>=2.5 in c:\users\86186\anaconda3\lib\site-packages (from FixedEffectModel) (3.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\86186\anaconda3\lib\site-packages (from pandas>=0.16.0->FixedEffectModel) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\86186\anaconda3\lib\site-packages (from pandas>=0.16.0->FixedEffectModel) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\86186\anaconda3\lib\site-packages (from pandas>=0.16.0->FixedEffectModel) (2023.3)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\86186\anaconda3\lib\site-packages (from statsmodels>=0.12.2->FixedEffectModel) (0.5.6)
# Requirement already satisfied: packaging>=21.3 in c:\users\86186\anaconda3\lib\site-packages (from statsmodels>=0.12.2->FixedEffectModel) (24.1)
# Requirement already satisfied: six in c:\users\86186\anaconda3\lib\site-packages (from patsy>=0.5.6->statsmodels>=0.12.2->FixedEffectModel) (1.16.0)
# Downloading FixedEffectModel-0.0.5-py3-none-any.whl (50 kB)
# Installing collected packages: FixedEffectModel
# Successfully installed FixedEffectModel-0.0.5

# %% [markdown]
# <h2>Estimate a few simple Ohlsson models, export the tables that you think are important to Excel, report them in your report and discuss the results.

# %%
model=smf.ols('stock_FinancialYEnd ~ BVE + BasicEPS', data=DATA)
results=model.fit()
print(results.summary())
# Out:
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     stock_FinancialYEnd   R-squared:                       0.239
# Model:                             OLS   Adj. R-squared:                  0.236
# Method:                  Least Squares   F-statistic:                     117.9
# Date:                 Wed, 11 Jun 2025   Prob (F-statistic):           2.79e-45
# Time:                         15:27:38   Log-Likelihood:                -4540.8
# No. Observations:                  756   AIC:                             9088.
# Df Residuals:                      753   BIC:                             9101.
# Df Model:                            2
# Covariance Type:             nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     81.5930      4.714     17.309      0.000      72.339      90.847
# BVE            0.9113      0.096      9.513      0.000       0.723       1.099
# BasicEPS       2.5804      0.375      6.883      0.000       1.844       3.316
# ==============================================================================
# Omnibus:                      349.948   Durbin-Watson:                   0.826
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1803.149
# Skew:                           2.095   Prob(JB):                         0.00
# Kurtosis:                       9.299   Cond. No.                         71.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# In the above regression model, the p-value for the coefficient of `BVE` is very small, indicating that `BVE` is a statistically significant predictor of `stock_FinancialYEnd`. This means there is strong evidence that `BVE` contributes to explaining the variations in `stock_FinancialYEnd`. If the p-value is large - greater than 10%, suggesting that `BVE` is not a statistically significant predictor at conventional levels.
#
# In the next model, we include `stock_FollowingQtrEnd` as an additional predictor variable to test its significance. You may consider experimenting with different combinations of variables to identify which ones significantly impact `stock_FinancialYEnd`. The results and significance of these variables will vary depending on the dataset used, so it is important to analyse the model output carefully for each specific case.
#
# You can also try using `profit` as the dependent (LHS) variable.

# %%
model=smf.ols('stock_FinancialYEnd ~ BVE + BasicEPS + stock_FollowingQtrEnd', data=DATA)
results=model.fit()
print(results.summary())
# Out:
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     stock_FinancialYEnd   R-squared:                       0.951
# Model:                             OLS   Adj. R-squared:                  0.951
# Method:                  Least Squares   F-statistic:                     4908.
# Date:                 Wed, 11 Jun 2025   Prob (F-statistic):               0.00
# Time:                         15:27:44   Log-Likelihood:                -3500.6
# No. Observations:                  756   AIC:                             7009.
# Df Residuals:                      752   BIC:                             7028.
# Df Model:                            3
# Covariance Type:             nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                 4.8421      1.398      3.464      0.001       2.098       7.586
# BVE                       0.1443      0.025      5.705      0.000       0.095       0.194
# BasicEPS               2.995e-05      0.098      0.000      1.000      -0.192       0.192
# stock_FollowingQtrEnd     0.9297      0.009    105.041      0.000       0.912       0.947
# ==============================================================================
# Omnibus:                      443.103   Durbin-Watson:                   2.319
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             8909.937
# Skew:                           2.224   Prob(JB):                         0.00
# Kurtosis:                      19.219   Cond. No.                         270.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# Add ESG scores as an independent variable

# %%
model=smf.ols('stock_FollowingQtrEnd ~ BVE + BasicEPS + ESG_Exposure', data=DATA)
results=model.fit()
print(results.summary())
# Out:
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     stock_FollowingQtrEnd   R-squared:                       0.268
# Model:                               OLS   Adj. R-squared:                  0.265
# Method:                    Least Squares   F-statistic:                     91.62
# Date:                   Wed, 11 Jun 2025   Prob (F-statistic):           1.53e-50
# Time:                           15:27:49   Log-Likelihood:                -4544.6
# No. Observations:                    756   AIC:                             9097.
# Df Residuals:                        752   BIC:                             9116.
# Df Model:                              3
# Covariance Type:               nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept      168.9398     12.656     13.349      0.000     144.095     193.784
# BVE              0.8311      0.096      8.625      0.000       0.642       1.020
# BasicEPS         2.7338      0.377      7.249      0.000       1.993       3.474
# ESG_Exposure    -1.9221      0.261     -7.362      0.000      -2.435      -1.410
# ==============================================================================
# Omnibus:                      422.759   Durbin-Watson:                   0.969
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4207.746
# Skew:                           2.346   Prob(JB):                         0.00
# Kurtosis:                      13.562   Cond. No.                         228.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
model=smf.ols('stock_FollowingQtrEnd ~ BVE + BasicEPS + ESG_Managed', data=DATA)
results=model.fit()
print(results.summary())
# Out:
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     stock_FollowingQtrEnd   R-squared:                       0.273
# Model:                               OLS   Adj. R-squared:                  0.270
# Method:                    Least Squares   F-statistic:                     94.21
# Date:                   Wed, 11 Jun 2025   Prob (F-statistic):           9.11e-52
# Time:                           15:27:59   Log-Likelihood:                -4541.8
# No. Observations:                    756   AIC:                             9092.
# Df Residuals:                        752   BIC:                             9110.
# Df Model:                              3
# Covariance Type:               nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept     150.5395      9.949     15.132      0.000     131.009     170.070
# BVE             0.8151      0.096      8.491      0.000       0.627       1.004
# BasicEPS        2.7026      0.376      7.192      0.000       1.965       3.440
# ESG_Managed    -3.2945      0.424     -7.765      0.000      -4.127      -2.462
# ==============================================================================
# Omnibus:                      422.531   Durbin-Watson:                   0.972
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4242.207
# Skew:                           2.341   Prob(JB):                         0.00
# Kurtosis:                      13.619   Cond. No.                         156.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# <h2>Estimate a few simple Ohlsson model with robust errors

# %% [markdown]
# You will need to conduct your own research to understand Ohlsson model with robust errors and interpret the statistics in this section. **Report your findings**.

# %%
model=smf.ols('stock_FinancialYEnd ~ BVE + BasicEPS', data=DATA)
results=model.fit(cov_type='HC1') #HC1 is the Huber-White standard errros, can try HC3 heteroscedasticity-consistent estimator
print(results.summary())
# Out:
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     stock_FinancialYEnd   R-squared:                       0.239
# Model:                             OLS   Adj. R-squared:                  0.236
# Method:                  Least Squares   F-statistic:                     33.10
# Date:                 Wed, 11 Jun 2025   Prob (F-statistic):           1.67e-14
# Time:                         15:28:06   Log-Likelihood:                -4540.8
# No. Observations:                  756   AIC:                             9088.
# Df Residuals:                      753   BIC:                             9101.
# Df Model:                            2
# Covariance Type:                   HC1
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     81.5930      5.873     13.893      0.000      70.083      93.103
# BVE            0.9113      0.226      4.040      0.000       0.469       1.353
# BasicEPS       2.5804      1.090      2.366      0.018       0.443       4.718
# ==============================================================================
# Omnibus:                      349.948   Durbin-Watson:                   0.826
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1803.149
# Skew:                           2.095   Prob(JB):                         0.00
# Kurtosis:                       9.299   Cond. No.                         71.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC1)

# %% [markdown]
# Add the ESG risk scores, try a different score one at a time, or a combination of different scores.

# %%
model=smf.ols('stock_FinancialYEnd ~ BVE + +BasicEPS + ESG_Index', data=DATA)
results=model.fit(cov_type='HC1') #HC1 is the Huber-White standard errros, can try HC3 heteroscedasticity-consistent estimator
print(results.summary())
# Out:
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     stock_FinancialYEnd   R-squared:                       0.302
# Model:                             OLS   Adj. R-squared:                  0.299
# Method:                  Least Squares   F-statistic:                     40.77
# Date:                 Wed, 11 Jun 2025   Prob (F-statistic):           2.03e-24
# Time:                         15:28:11   Log-Likelihood:                -4508.0
# No. Observations:                  756   AIC:                             9024.
# Df Residuals:                      752   BIC:                             9043.
# Df Model:                            3
# Covariance Type:                   HC1
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     81.5806      5.959     13.691      0.000      69.902      93.259
# BVE            0.9149      0.210      4.353      0.000       0.503       1.327
# BasicEPS       2.5584      1.032      2.478      0.013       0.535       4.582
# ESG_Index    -18.2231      2.048     -8.899      0.000     -22.236     -14.210
# ==============================================================================
# Omnibus:                      329.064   Durbin-Watson:                   0.849
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1780.006
# Skew:                           1.922   Prob(JB):                         0.00
# Kurtosis:                       9.460   Cond. No.                         71.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC1)

# %% [markdown]
# <h3>Extract the summary output table

# %% [markdown]
# Must run the following codes right after the model that's been estimated; if you want to report a few different model results, run the following codes after each model estimation, remember to give a differet name in the last line, i.e., 'summary_output_1(2,3,4,etc.)_xlsx'. You will find the output xlsx file under the same folder where you saved this jupter notebook.

# %%
summary = results.summary() 

#extract observations, adjusted r2, f-stats, log likelihood

obs = results.nobs
adjusted_r2 = results.rsquared_adj
f_stats = results.fvalue
log_likelihood = results.llf

#convert the summary output table into a DataFrame

summary_df = pd.read_html(summary.tables[1].as_html(), header=0, index_col=0)[0]

#Add observations, adjusted R-squared, F-statistics, and log-likelihood to the DataFrame
summary_df['Observations'] = obs
summary_df['Adjusted R-squared'] = adjusted_r2
summary_df['F-Statistic'] = f_stats
summary_df['Log-Likelihood'] = log_likelihood

#Export the DataFrame to an Excel file, give a different name if you are exporting a few tables of results, i.e., 'summary_output_1' etc.
#you can find the xlsx file in the same folder where you keep all your Jupyter notebookds and data
#go to the foloder and download it, format it then present it in your report

summary_df.to_excel('summary_output.xlsx')
# Out:
# C:\Users\86186\AppData\Local\Temp\ipykernel_37200\2955853338.py:12: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   summary_df = pd.read_html(summary.tables[1].as_html(), header=0, index_col=0)[0]

# %% [markdown]
# <h2>Install linearmodels package to estimate panel data with fixed effects

# %%
pip install linearmodels
# Out:
# Collecting linearmodelsNote: you may need to restart the kernel to use updated packages.
#
#   Downloading linearmodels-6.1-cp312-cp312-win_amd64.whl.metadata (8.1 kB)
# Requirement already satisfied: numpy<3,>=1.22.3 in c:\users\86186\anaconda3\lib\site-packages (from linearmodels) (1.26.4)
# Requirement already satisfied: pandas>=1.4.0 in c:\users\86186\anaconda3\lib\site-packages (from linearmodels) (2.2.2)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\86186\anaconda3\lib\site-packages (from linearmodels) (1.13.1)
# Requirement already satisfied: statsmodels>=0.13.0 in c:\users\86186\anaconda3\lib\site-packages (from linearmodels) (0.14.2)
# Requirement already satisfied: mypy-extensions>=0.4 in c:\users\86186\anaconda3\lib\site-packages (from linearmodels) (1.0.0)
# Collecting Cython>=3.0.10 (from linearmodels)
#   Downloading cython-3.1.2-cp312-cp312-win_amd64.whl.metadata (6.0 kB)
# Collecting pyhdfe>=0.1 (from linearmodels)
#   Downloading pyhdfe-0.2.0-py3-none-any.whl.metadata (4.0 kB)
# Collecting formulaic>=1.0.0 (from linearmodels)
#   Downloading formulaic-1.1.1-py3-none-any.whl.metadata (6.9 kB)
# Collecting setuptools-scm<9.0.0,>=8.0.0 (from setuptools-scm[toml]<9.0.0,>=8.0.0->linearmodels)
#   Downloading setuptools_scm-8.3.1-py3-none-any.whl.metadata (7.0 kB)
# Collecting interface-meta>=1.2.0 (from formulaic>=1.0.0->linearmodels)
#   Downloading interface_meta-1.3.0-py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\86186\anaconda3\lib\site-packages (from formulaic>=1.0.0->linearmodels) (4.13.2)
# Requirement already satisfied: wrapt>=1.0 in c:\users\86186\anaconda3\lib\site-packages (from formulaic>=1.0.0->linearmodels) (1.14.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\86186\anaconda3\lib\site-packages (from pandas>=1.4.0->linearmodels) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\86186\anaconda3\lib\site-packages (from pandas>=1.4.0->linearmodels) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\86186\anaconda3\lib\site-packages (from pandas>=1.4.0->linearmodels) (2023.3)
# Requirement already satisfied: packaging>=20 in c:\users\86186\anaconda3\lib\site-packages (from setuptools-scm<9.0.0,>=8.0.0->setuptools-scm[toml]<9.0.0,>=8.0.0->linearmodels) (24.1)
# Requirement already satisfied: setuptools in c:\users\86186\anaconda3\lib\site-packages (from setuptools-scm<9.0.0,>=8.0.0->setuptools-scm[toml]<9.0.0,>=8.0.0->linearmodels) (75.1.0)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\86186\anaconda3\lib\site-packages (from statsmodels>=0.13.0->linearmodels) (0.5.6)
# Requirement already satisfied: six in c:\users\86186\anaconda3\lib\site-packages (from patsy>=0.5.6->statsmodels>=0.13.0->linearmodels) (1.16.0)
# Downloading linearmodels-6.1-cp312-cp312-win_amd64.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ------------ --------------------------- 0.5/1.7 MB 2.8 MB/s eta 0:00:01
#    ------------------------------- -------- 1.3/1.7 MB 3.7 MB/s eta 0:00:01
#    ---------------------------------------- 1.7/1.7 MB 3.4 MB/s eta 0:00:00
# Downloading cython-3.1.2-cp312-cp312-win_amd64.whl (2.7 MB)
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    ------- -------------------------------- 0.5/2.7 MB 3.4 MB/s eta 0:00:01
#    ------------------- -------------------- 1.3/2.7 MB 4.0 MB/s eta 0:00:01
#    ----------------------------------- ---- 2.4/2.7 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------- 2.7/2.7 MB 3.8 MB/s eta 0:00:00
# Downloading formulaic-1.1.1-py3-none-any.whl (115 kB)
# Downloading pyhdfe-0.2.0-py3-none-any.whl (19 kB)
# Downloading setuptools_scm-8.3.1-py3-none-any.whl (43 kB)
# Downloading interface_meta-1.3.0-py3-none-any.whl (14 kB)
# Installing collected packages: setuptools-scm, interface-meta, Cython, pyhdfe, formulaic, linearmodels
# Successfully installed Cython-3.1.2 formulaic-1.1.1 interface-meta-1.3.0 linearmodels-6.1 pyhdfe-0.2.0 setuptools-scm-8.3.1

# %% [markdown]
# <h2>From linearmodels import PanelOLS the fixed effect package

# %%
from linearmodels import PanelOLS
import statsmodels.api as sm
import pandas as pd

# %% [markdown]
# <h2>Estimate a fixed effect model, print out the stats, export the results, report them and discuss the results in your report

# %% [markdown]
# To estimate a fixed effect model first must organise the data into panel data and let pandas know what variable (column name) is 'entity' and what variable (column name) is 'time'
#
# https://bashtage.github.io/linearmodels/panel/panel/linearmodels.panel.model.PanelOLS.html
# https://timeseriesreasoning.com/contents/the-fixed-effects-regression-model-for-panel-data-sets/#google_vignette
# https://swh.princeton.edu/~otorres/Panel101.pdf
#
# We encourage you to write differnt codes to find a best fit model, i.e., all coefficients are significant (if possible) with high R square. You can consult your lecturers about how you can find the best model using panel data.
#
# If the fixed effect models perform poorer than the simple OLS or simple OLS with robust errors, **include your results in your report as sensitive analyses** and state that you have tried other models; then focus on interpretting the models that yield the best results.

# %% [markdown]
# Step 1: Organise the data into a panel data format.
# Specify `Company` and `Year` are the fixed effects.
# The order matters!
# The first in the `set_index` code tells Python that variable is the 'entity' fixed effect, the second is the 'time' fixed effect.

# %%
FixedEffect=pd.DataFrame(DATA).set_index(['Company', 'Year'])

# %% [markdown]
# Step 2: Define `stock_FinancialYEnd` as the dependent variable (y) and `BVE`, `BasicEPS` as the independent variables (X)

# %%
#define the dependent variable
y = FixedEffect['stock_FinancialYEnd']

#define the independent variables and add constant to the model
X = sm.add_constant(FixedEffect[['BVE', 'BasicEPS']])

# %% [markdown]
# Step 3: Estimate the fixed effect model with entity fixed effect; and print the results.

# %%
Model_F = PanelOLS(y, X, entity_effects=True) #entity here is 'Company' which is the firm fixed effect
results = Model_F.fit()
print(results)
# Out:
#                            PanelOLS Estimation Summary
# =================================================================================
# Dep. Variable:     stock_FinancialYEnd   R-squared:                        0.0923
# Estimator:                    PanelOLS   R-squared (Between):              0.2156
# No. Observations:                  756   R-squared (Within):               0.0923
# Date:                 Wed, Jun 11 2025   R-squared (Overall):              0.2027
# Time:                         15:35:32   Log-likelihood                   -3753.8
# Cov. Estimator:             Unadjusted
#                                          F-statistic:                      28.727
# Entities:                          189   P-value                           0.0000
# Avg Obs:                        4.0000   Distribution:                   F(2,565)
# Min Obs:                        4.0000
# Max Obs:                        4.0000   F-statistic (robust):             28.727
#                                          P-value                           0.0000
# Time periods:                        4   Distribution:                   F(2,565)
# Avg Obs:                        189.00
# Min Obs:                        189.00
# Max Obs:                        189.00
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const          89.536     6.1183     14.634     0.0000      77.518      101.55
# BVE            0.9964     0.1789     5.5683     0.0000      0.6449      1.3479
# BasicEPS       0.4415     0.1765     2.5010     0.0127      0.0948      0.7881
# ==============================================================================
#
# F-test for Poolability: 21.098
# P-value: 0.0000
# Distribution: F(188,565)
#
# Included effects: Entity

# %% [markdown]
# You can specify `SECTOR` as the entity fixed effect. We encourage you to write different codes to find a best fit model.

# %%
FixedEffect=pd.DataFrame(DATA).set_index(['SECTOR', 'Year'])

y = FixedEffect['stock_FinancialYEnd']
X = sm.add_constant(FixedEffect[['BVE', 'BasicEPS']])

Model_F = PanelOLS(y, X, entity_effects=True) #entity here is 'SECTOR' which is the SECTOR fixed effect
results = Model_F.fit()
print(results)
# Out:
#                            PanelOLS Estimation Summary
# =================================================================================
# Dep. Variable:     stock_FinancialYEnd   R-squared:                        0.2611
# Estimator:                    PanelOLS   R-squared (Between):              0.1601
# No. Observations:                  756   R-squared (Within):               0.2611
# Date:                 Wed, Jun 11 2025   R-squared (Overall):              0.2370
# Time:                         15:35:38   Log-likelihood                   -4434.4
# Cov. Estimator:             Unadjusted
#                                          F-statistic:                      131.48
# Entities:                           10   P-value                           0.0000
# Avg Obs:                        75.600   Distribution:                   F(2,744)
# Min Obs:                        56.000
# Max Obs:                        80.000   F-statistic (robust):             131.48
#                                          P-value                           0.0000
# Time periods:                        4   Distribution:                   F(2,744)
# Avg Obs:                        189.00
# Min Obs:                        189.00
# Max Obs:                        189.00
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const          82.020     4.2259     19.409     0.0000      73.724      90.316
# BVE            0.9668     0.0885     10.929     0.0000      0.7931      1.1404
# BasicEPS       2.1174     0.3312     6.3938     0.0000      1.4672      2.7675
# ==============================================================================
#
# F-test for Poolability: 26.875
# P-value: 0.0000
# Distribution: F(9,744)
#
# Included effects: Entity

# %% [markdown]
# Step 4: Estimate the fixed effect model with both the `Company` and `Year` fixed effect; print the results.
# In the following model, we change entity back to `Company`.

# %%
FixedEffect=pd.DataFrame(DATA).set_index(['Company', 'Year'])

Model_F = PanelOLS(y, X, entity_effects=True, time_effects=True) 

#entity here is 'Company' which is the firm fixed effect; time here is 'Year' which is the time fixed effect

results = Model_F.fit()
print(results)
# Out:
#                            PanelOLS Estimation Summary
# =================================================================================
# Dep. Variable:     stock_FinancialYEnd   R-squared:                        0.2578
# Estimator:                    PanelOLS   R-squared (Between):              0.1596
# No. Observations:                  756   R-squared (Within):               0.2611
# Date:                 Wed, Jun 11 2025   R-squared (Overall):              0.2368
# Time:                         15:35:43   Log-likelihood                   -4430.9
# Cov. Estimator:             Unadjusted
#                                          F-statistic:                      128.69
# Entities:                           10   P-value                           0.0000
# Avg Obs:                        75.600   Distribution:                   F(2,741)
# Min Obs:                        56.000
# Max Obs:                        80.000   F-statistic (robust):             128.69
#                                          P-value                           0.0000
# Time periods:                        4   Distribution:                   F(2,741)
# Avg Obs:                        189.00
# Min Obs:                        189.00
# Max Obs:                        189.00
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const          82.419     4.2207     19.527     0.0000      74.133      90.705
# BVE            0.9582     0.0884     10.845     0.0000      0.7847      1.1316
# BasicEPS       2.0978     0.3322     6.3154     0.0000      1.4457      2.7499
# ==============================================================================
#
# F-test for Poolability: 20.826
# P-value: 0.0000
# Distribution: F(12,741)
#
# Included effects: Entity, Time

# %% [markdown]
# Add other variables in the right hand side, i.e., `ESG_Index`. We also cluster the robust errors by entity and time in the estimation. Try different model specifications to find the best model, **report and interpret the results**.

# %%
FixedEffect=pd.DataFrame(DATA).set_index(['SECTOR', 'Year'])
y = FixedEffect['stock_FinancialYEnd']
X = sm.add_constant(FixedEffect[['BVE', 'BasicEPS', 'ESG_Index']])

#Try all different ESG risk scores and interpret the results accordingly

Model_F = PanelOLS(y, X, entity_effects=True, time_effects=True) 

#Try different clusters
results = Model_F.fit(cov_type='clustered', cluster_entity=True, cluster_time=True)
results.summary
# Out:
# <class 'linearmodels.compat.statsmodels.Summary'>
# """
#                            PanelOLS Estimation Summary
# =================================================================================
# Dep. Variable:     stock_FinancialYEnd   R-squared:                        0.2815
# Estimator:                    PanelOLS   R-squared (Between):              0.3640
# No. Observations:                  756   R-squared (Within):               0.2838
# Date:                 Wed, Jun 11 2025   R-squared (Overall):              0.2992
# Time:                         15:35:48   Log-likelihood                   -4418.7
# Cov. Estimator:              Clustered
#                                          F-statistic:                      96.633
# Entities:                           10   P-value                           0.0000
# Avg Obs:                        75.600   Distribution:                   F(3,740)
# Min Obs:                        56.000
# Max Obs:                        80.000   F-statistic (robust):             90.018
#                                          P-value                           0.0000
# Time periods:                        4   Distribution:                   F(3,740)
# Avg Obs:                        189.00
# Min Obs:                        189.00
# Max Obs:                        189.00
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const          81.240     7.3160     11.105     0.0000      66.878      95.603
# BVE            0.9919     0.1262     7.8566     0.0000      0.7440      1.2397
# BasicEPS       2.0986     0.9413     2.2296     0.0261      0.2508      3.9464
# ESG_Index     -16.120     4.0398    -3.9903     0.0001     -24.051     -8.1893
# ==============================================================================
#
# F-test for Poolability: 16.448
# P-value: 0.0000
# Distribution: F(12,740)
#
# Included effects: Entity, Time
# """

# %%
params_df = pd.DataFrame({
    'Parameter': results.params,
    'Std. Err.': results.std_errors,
    'T-stat': results.tstats,
    'P-value': results.pvalues,
    'Lower CI': results.conf_int().iloc[:, 0],
    'Upper CI': results.conf_int().iloc[:, 1]
})

# Reset index to include the parameter names as a column
params_df = params_df.reset_index().rename(columns={'index': 'Variable'})

params_df[' '] = np.nan  # Adds an empty column named with a space
# Step 3: Add additional model statistics to the DataFrame
additional_stats = {
    'R-squared': [results.rsquared],
    'No. Observations': [results.nobs],
}

# Convert the additional statistics dictionary into a DataFrame
additional_stats_df = pd.DataFrame(additional_stats)

# Step 4: Combine parameter estimates with the additional statistics
combined_df = pd.concat([params_df, additional_stats_df], axis=1)

combined_df.to_excel('panel_ols_summary_output.xlsx', index=False, float_format=None)

print("Summary output exported to 'panel_ols_summary_output.xlsx'") ##use different file names for different models otherwise the file will overwrite saved results
# Out:
# Summary output exported to 'panel_ols_summary_output.xlsx'

# %% [markdown]
# <h2>Optional: Additional analyses

# %% [markdown]
# <H3>Drop SECTOR = Energy, renmae the dataframe as 'data'

# %%
data = DATA[DATA['SECTOR'] != 9]
FixedEffect=pd.DataFrame(data).set_index(['SECTOR', 'Year'])
y = FixedEffect['stock_FinancialYEnd']
X = sm.add_constant(FixedEffect[['BVE', 'BasicEPS', 'ESG_Index']])

#Try all different ESG risk scores and interpret the results accordingly

Model_F = PanelOLS(y, X, entity_effects=True, time_effects=True) 

#Try different clusters
results = Model_F.fit(cov_type='clustered', cluster_entity=True, cluster_time=True)
results.summary
# Out:
# <class 'linearmodels.compat.statsmodels.Summary'>
# """
#                            PanelOLS Estimation Summary
# =================================================================================
# Dep. Variable:     stock_FinancialYEnd   R-squared:                        0.2797
# Estimator:                    PanelOLS   R-squared (Between):              0.4911
# No. Observations:                  676   R-squared (Within):               0.2824
# Date:                 Wed, Jun 11 2025   R-squared (Overall):              0.3261
# Time:                         15:35:56   Log-likelihood                   -3977.5
# Cov. Estimator:              Clustered
#                                          F-statistic:                      85.544
# Entities:                            9   P-value                           0.0000
# Avg Obs:                        75.111   Distribution:                   F(3,661)
# Min Obs:                        56.000
# Max Obs:                        80.000   F-statistic (robust):             61.020
#                                          P-value                           0.0000
# Time periods:                        4   Distribution:                   F(3,661)
# Avg Obs:                        169.00
# Min Obs:                        169.00
# Max Obs:                        169.00
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const          88.770     8.3626     10.615     0.0000      72.349      105.19
# BVE            1.0025     0.1421     7.0543     0.0000      0.7234      1.2815
# BasicEPS       2.0314     0.8981     2.2618     0.0240      0.2679      3.7950
# ESG_Index     -15.883     4.0397    -3.9317     0.0001     -23.815     -7.9508
# ==============================================================================
#
# F-test for Poolability: 10.853
# P-value: 0.0000
# Distribution: F(11,661)
#
# Included effects: Entity, Time
# """

# %% [markdown]
# <h4>There is a slight improvement in the model fit.

# %%
import pandas as pd
import statsmodels.api as sm
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# <h3>Plot a few scenarios to visualise the impacts of varying independent variables on the dependent variable

# %%
FixedEffect=pd.DataFrame(DATA).set_index(['SECTOR', 'Year'])
y = FixedEffect['stock_FinancialYEnd']
X = sm.add_constant(FixedEffect[['BVE', 'BasicEPS', 'ESG_Index']])

Model_F = PanelOLS(y, X, entity_effects=True, time_effects=True) 

#clusters
results = Model_F.fit(cov_type='clustered', cluster_entity=True, cluster_time=True)
results.summary
# Out:
# <class 'linearmodels.compat.statsmodels.Summary'>
# """
#                            PanelOLS Estimation Summary
# =================================================================================
# Dep. Variable:     stock_FinancialYEnd   R-squared:                        0.2815
# Estimator:                    PanelOLS   R-squared (Between):              0.3640
# No. Observations:                  756   R-squared (Within):               0.2838
# Date:                 Wed, Jun 11 2025   R-squared (Overall):              0.2992
# Time:                         15:36:03   Log-likelihood                   -4418.7
# Cov. Estimator:              Clustered
#                                          F-statistic:                      96.633
# Entities:                           10   P-value                           0.0000
# Avg Obs:                        75.600   Distribution:                   F(3,740)
# Min Obs:                        56.000
# Max Obs:                        80.000   F-statistic (robust):             90.018
#                                          P-value                           0.0000
# Time periods:                        4   Distribution:                   F(3,740)
# Avg Obs:                        189.00
# Min Obs:                        189.00
# Max Obs:                        189.00
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const          81.240     7.3160     11.105     0.0000      66.878      95.603
# BVE            0.9919     0.1262     7.8566     0.0000      0.7440      1.2397
# BasicEPS       2.0986     0.9413     2.2296     0.0261      0.2508      3.9464
# ESG_Index     -16.120     4.0398    -3.9903     0.0001     -24.051     -8.1893
# ==============================================================================
#
# F-test for Poolability: 16.448
# P-value: 0.0000
# Distribution: F(12,740)
#
# Included effects: Entity, Time
# """

# %%
import pandas as pd
import statsmodels.api as sm
import numpy as np
import matplotlib.pyplot as plt

# Step 1: Load the data
DATA = pd.read_csv('DATA.csv')  # Assuming the data file is 'DATA.csv'

# Step 2: Define independent and dependent variables
# Define dependent variable (stock price: stock_FinancialYEnd)
y = DATA['stock_FinancialYEnd']

# Define independent variables (BVE, BasicEPS, ESG_Index)
X = DATA[['BVE', 'BasicEPS', 'ESG_Index']]

# Step 3: Add constant to the model
X = sm.add_constant(X)

# Step 4: Fit the OLS regression model
model = sm.OLS(y, X).fit()

# Print model summary
print(model.summary())
# Out:
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     stock_FinancialYEnd   R-squared:                       0.302
# Model:                             OLS   Adj. R-squared:                  0.299
# Method:                  Least Squares   F-statistic:                     108.3
# Date:                 Wed, 11 Jun 2025   Prob (F-statistic):           2.76e-58
# Time:                         15:36:07   Log-Likelihood:                -4508.0
# No. Observations:                  756   AIC:                             9024.
# Df Residuals:                      752   BIC:                             9043.
# Df Model:                            3
# Covariance Type:             nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         81.5806      4.517     18.061      0.000      72.713      90.448
# BVE            0.9149      0.092      9.966      0.000       0.735       1.095
# BasicEPS       2.5584      0.359      7.121      0.000       1.853       3.264
# ESG_Index    -18.2231      2.209     -8.249      0.000     -22.560     -13.886
# ==============================================================================
# Omnibus:                      329.064   Durbin-Watson:                   0.849
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1780.006
# Skew:                           1.922   Prob(JB):                         0.00
# Kurtosis:                       9.460   Cond. No.                         71.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Step 5: Define scenarios with all variables
scenarios = {
    'Baseline': {'BasicEPS': 1.0, 'BVE': 1.0, 'ESG_Index': 1.0},  # Baseline scenario
    'Increase BVE by 10%': {'BVE': 1.10, 'ESG_Index': 1.0, 'BasicEPS': 1.0},
    'Decrease BVE by 10%': {'BVE': 0.90, 'ESG_Index': 1.0, 'BasicEPS': 1.0},
    'Increase ESG_Index by 20%': {'BVE': 1.0, 'ESG_Index': 1.20, 'BasicEPS': 1.0},
    'Decrease ESG_Index by 20%': {'BVE': 1.0, 'ESG_Index': 0.80, 'BasicEPS': 1.0},
    'Increase BasicEPS by 15%': {'BVE': 1.0, 'ESG_Index': 1.0, 'BasicEPS': 1.15},
    'Decrease BasicEPS by 15%': {'BVE': 1.0, 'ESG_Index': 1.0, 'BasicEPS': 0.85},
}

# %%
# Step 6: Run simulations for different scenarios
results = {}

for scenario, changes in scenarios.items():
    # Modify independent variables based on the scenario
    DATA['BasicEPS_new'] = DATA['BasicEPS'] * changes['BasicEPS']
    DATA['ESG_Index_new'] = DATA['ESG_Index'] * changes['ESG_Index']
    DATA['BVE_new'] = DATA['BVE'] * changes['BVE']

# Build a new independent variable matrix using the modified data
    X_new = DATA[['BasicEPS_new', 'BVE_new', 'ESG_Index_new']]
    X_new = sm.add_constant(X_new)
    
    # Predict the stock price using the regression model
    stock_FinancialYEnd_predicted = model.predict(X_new)
    
    # Store results
    results[scenario] = stock_FinancialYEnd_predicted

# %%
# Step 7: Visualize the stock price predictions for different scenarios
plt.figure(figsize=(10,6))
plt.plot(DATA['stock_FinancialYEnd'], label='Actual Stock Price', color='blue', marker='o')
for scenario, prediction in results.items():
    plt.plot(prediction, label=f'Predicted Stock Price ({scenario})', marker='x')
plt.title('What-If Simulation: Impact of Changes in BasicEPS, BVE, and ESG_Index')
plt.xlabel('Data Points')
plt.ylabel('Stock Price')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Step 8: Analyze the sensitivity of each variable
# Calculate the mean change in each scenario
for scenario, prediction in results.items():
    mean_predicted = prediction.mean()
    print(f"Mean predicted stock price in the {scenario} scenario: {mean_predicted}")

# Step 9: Verify the model assumptions
# Compare the deviation of each scenario from the baseline
baseline_mean = results['Baseline'].mean()
for scenario, prediction in results.items():
    mean_predicted = prediction.mean()
    deviation = abs(mean_predicted - baseline_mean)
    print(f"Deviation from baseline in the {scenario} scenario: {deviation}")
# Out:
# Mean predicted stock price in the Baseline scenario: 175.49659324663133
# Mean predicted stock price in the Increase BVE by 10% scenario: 184.42144107616062
# Mean predicted stock price in the Decrease BVE by 10% scenario: 166.57174541710208
# Mean predicted stock price in the Increase ESG_Index by 20% scenario: 175.49659324663133
# Mean predicted stock price in the Decrease ESG_Index by 20% scenario: 175.4965932466313
# Mean predicted stock price in the Increase BasicEPS by 15% scenario: 176.19672696918772
# Mean predicted stock price in the Decrease BasicEPS by 15% scenario: 174.79645952407495
# Deviation from baseline in the Baseline scenario: 0.0
# Deviation from baseline in the Increase BVE by 10% scenario: 8.924847829529284
# Deviation from baseline in the Decrease BVE by 10% scenario: 8.924847829529256
# Deviation from baseline in the Increase ESG_Index by 20% scenario: 0.0
# Deviation from baseline in the Decrease ESG_Index by 20% scenario: 2.842170943040401e-14
# Deviation from baseline in the Increase BasicEPS by 15% scenario: 0.7001337225563873
# Deviation from baseline in the Decrease BasicEPS by 15% scenario: 0.7001337225563873

# %% [markdown]
# <h1>The End
